# %% [markdown]
# # What Makes Movies Earn More Money?
# #### Stephanie Qie & Nikhil Pateel

# %% [markdown]
# ## Introduction
#
# Movies play an important role in today's popular culture and media, as they are one of the largest forms of entertainment and one of the most profitable industries in our society.
#
# From large movie studios to movie analysts, many people have tried to analyze what makes a movie earn more money.
#
# In this tutorial, we will ....

# %% [markdown]
# ## 0.0 - Required Libraries
#
# We need the following libraries
# + `pandas` - For storing data
# + `matplotlib` - For plotting data
# + `sci-kit learn` - has a variety of

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn import model_selection
from statsmodels import api as sm
import requests
import numpy as np

# %% [markdown]
# ## 1.0 Dataset Source
#
# Our dataset comes from the following source
# + [kaggle](https://www.kaggle.com/tmdb/tmdb-movie-metadata)

# %% [markdown]
# ## 1.1 Grabbing Data

# %% [markdown]
# Load the .csv files which we downloaded from kaggle, and display the first few rows to have a general understanding of the data.

# %%
df = pd.read_csv('tmdb_5000_movies.csv')
cast = pd.read_csv('tmdb_5000_credits.csv')

display(df.head())
display(cast.head())
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %% [markdown]
# ## 1.3 Tidying Data

# %% [markdown]
# Joined the two tables by movie title, so that all of the data is in one table.

# %%
df = df.set_index('original_title').join(cast.set_index('title'))
df = df.reset_index()
display(df.head())
# Out:
#                                   index    budget  \
# 0                               #Horror   1500000
# 1                       $upercapitalist         0
# 2                  (500) Days of Summer   7500000
# 3  ...E tu vivrai nel terrore! L'aldilà         0
# 4                   10 Cloverfield Lane  15000000
#
#                                               genres  \
# 0  [{"id": 18, "name": "Drama"}, {"id": 9648, "na...
# 1                   [{"id": 53, "name": "Thriller"}]
# 2  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3                     [{"id": 27, "name": "Horror"}]
# 4  [{"id": 53, "name": "Thriller"}, {"id": 878, "...
#
#                             homepage      id  \
# 0      http://www.hashtaghorror.com/  301325
# 1        http://supercapitalist.net/  119458
# 2                 http://500days.com   19913
# 3                                NaN   19204
# 4  http://www.10cloverfieldlane.com/  333371
#
#                                             keywords original_language  \
# 0                                                 []                de
# 1                                                 []                en
# 2  [{"id": 248, "name": "date"}, {"id": 572, "nam...                en
# 3  [{"id": 612, "name": "hotel"}, {"id": 1706, "n...                it
# 4  [{"id": 1930, "name": "kidnapping"}, {"id": 23...                en
#
#                                             overview  popularity  \
# 0  Inspired by actual events, a group of 12 year ...    2.815228
# 1  A maverick New York hedge fund trader with unc...    0.174311
# 2  Tom (Joseph Gordon-Levitt), greeting-card writ...   45.610993
# 3  A young woman inherits an old hotel in Louisia...    8.022122
# 4  After a car accident, Michelle awakens to find...   53.698683
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "AST Studios", "id": 75277}, {"name"...  ...    90.0
# 1                                                 []  ...   103.0
# 2  [{"name": "Fox Searchlight Pictures", "id": 43...  ...    95.0
# 3             [{"name": "Fulvia Film", "id": 13682}]  ...    87.0
# 4  [{"name": "Paramount Pictures", "id": 4}, {"na...  ...   103.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 3  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                              tagline                 title  \
# 0                                 Death is trending.               #Horror
# 1                                     Money for Life       Supercapitalist
# 2                It was almost like falling in love.  (500) Days of Summer
# 3  The seven dreaded gateways to Hell are conceal...            The Beyond
# 4                       Monsters come in many forms.   10 Cloverfield Lane
#
#   vote_average vote_count  movie_id  \
# 0          3.3         52  301325.0
# 1          3.5          2       NaN
# 2          7.2       2904   19913.0
# 3          6.6        117       NaN
# 4          6.8       2468  333371.0
#
#                                                 cast  \
# 0  [{"cast_id": 0, "character": "Alex's 12-Step F...
# 1                                                NaN
# 2  [{"cast_id": 4, "character": "Tom Hansen", "cr...
# 3                                                NaN
# 4  [{"cast_id": 2, "character": "Michelle", "cred...
#
#                                                 crew
# 0  [{"credit_id": "545bbac70e0a261fb6002329", "de...
# 1                                                NaN
# 2  [{"credit_id": "52fe47f99251416c750abaa5", "de...
# 3                                                NaN
# 4  [{"credit_id": "57627624c3a3680682000872", "de...
#
# [5 rows x 23 columns]

# %% [markdown]
# As seen in the table above, some of the columns (ie. genres, production companies, production countries, spoken languages, cast, and crew) have more than element per cell. We will be converting those cells into data structures to make it easier to access all of the data in those cells.

# %% [markdown]
# First we will modify the genres. As shown below, a movie can have multiple genres, and each genre contains an id and name. We will make it so that for each movie, all of their genres are stored in an array, and each genre element will be a dictionary with keys for its id and name.

# %%
df.iloc[0]["genres"]
# Out:
# '[{"id": 18, "name": "Drama"}, {"id": 9648, "name": "Mystery"}, {"id": 27, "name": "Horror"}, {"id": 53, "name": "Thriller"}]'

# %%
import re

#go through each row
for index, row in df.iterrows():
    
    genres = []
    line = row["genres"]
    cur_genres = line.split('},')
    
    del cur_genres[-1]
  
    #transform info for each genre
    for genre in cur_genres:
        m = re.search("(\d+), \"name\": \"(\w+)", genre)
        cur_id = m.groups()[0]
        cur_name = m.groups()[1]
        
        cur_info = {}
        cur_info["id"] = cur_id
        cur_info["name"] = cur_name
        
        genres.append(cur_info)
        
    df.at[index, "genres"] = genres

# %% [markdown]
# Next we will modify the production companies. As shown below, a movie can have multiple production companies, and each production company has a name and id. We will make it so that for each movie, all of their production companies are stored in an array, and each production company element will be a dictionary with keys for its name and id.

# %%
df.iloc[0]["production_companies"]
# Out:
# '[{"name": "AST Studios", "id": 75277}, {"name": "Lowland Pictures", "id": 75278}]'

# %%
#go through each row
for index, row in df.iterrows():
    
    p_comps = []
    line = row["production_companies"]
    cur_p_comps = line.split('},')
    
    del cur_p_comps[-1]
  
    #transform info for each genre
    for p_comp in cur_p_comps:
        m = re.search("name\": \"(.+)\", \"id\": (\d+)", p_comp)
        cur_name = m.groups()[0]
        cur_id = m.groups()[1]
        
        cur_info = {}
        cur_info["name"] = cur_name
        cur_info["id"] = cur_id
        
        p_comps.append(cur_info)
        
    df.at[index, "production_companies"] = p_comps

# %% [markdown]
# Next we will modify the production countries. As shown below, a movie can have multiple production countries, and each production country has an iso_3166_1 and a name.

# %%
df.iloc[0]["production_countries"]
# Out:
# '[{"iso_3166_1": "US", "name": "United States of America"}]'

# %%
#go through each row
for index, row in df.iterrows():
    
    p_countries = []
    line = row["production_countries"]
    cur_p_countries = line.split('},')
    
    del cur_p_countries[-1]
  
    #transform info for each genre
    for p_country in cur_p_countries:
        m = re.search("\"iso_3166_1\": \"(.+)\", \"name\": \"(.+)\"", p_country)
        cur_iso_3166_1 = m.groups()[0]
        cur_name = m.groups()[1]
        
        cur_info = {}
        cur_info["iso_3166_1"] = cur_iso_3166_1
        cur_info["name"] = cur_name
        
        p_countries.append(cur_info)
        
    df.at[index, "production_countries"] = p_countries

# %% [markdown]
# Next we will modify the spoken languages. As shown below, a movie can have multiple spoken languages, and each spoken language has an iso_639_1 and a name.

# %%
df.iloc[0]["spoken_languages"]
# Out:
# '[{"iso_639_1": "en", "name": "English"}, {"iso_639_1": "es", "name": "Espa\\u00f1ol"}]'

# %%
#go through each row
for index, row in df.iterrows():
    
    s_langs = []
    line = row["spoken_languages"]
    cur_s_langs = line.split('},')
    
    del cur_s_langs[-1]
  
    #transform info for each genre
    for s_lang in cur_s_langs:
        
        m = re.search("\"iso_639_1\": \"(.*)\", \"name\": \"(.*)\"", s_lang)
        
        cur_iso_639_1 = m.groups()[0]
        cur_name = m.groups()[1]

        cur_info = {}
        cur_info["iso_639_1"] = cur_iso_639_1
        cur_info["name"] = cur_name

        s_langs.append(cur_info)
        
    df.at[index, "spoken_languages"] = s_langs
    
display(df.head())
# Out:
#                                   index    budget  \
# 0                               #Horror   1500000
# 1                       $upercapitalist         0
# 2                  (500) Days of Summer   7500000
# 3  ...E tu vivrai nel terrore! L'aldilà         0
# 4                   10 Cloverfield Lane  15000000
#
#                                               genres  \
# 0  [{'id': '18', 'name': 'Drama'}, {'id': '9648',...
# 1                                                 []
# 2  [{'id': '35', 'name': 'Comedy'}, {'id': '18', ...
# 3                                                 []
# 4  [{'id': '53', 'name': 'Thriller'}, {'id': '878...
#
#                             homepage      id  \
# 0      http://www.hashtaghorror.com/  301325
# 1        http://supercapitalist.net/  119458
# 2                 http://500days.com   19913
# 3                                NaN   19204
# 4  http://www.10cloverfieldlane.com/  333371
#
#                                             keywords original_language  \
# 0                                                 []                de
# 1                                                 []                en
# 2  [{"id": 248, "name": "date"}, {"id": 572, "nam...                en
# 3  [{"id": 612, "name": "hotel"}, {"id": 1706, "n...                it
# 4  [{"id": 1930, "name": "kidnapping"}, {"id": 23...                en
#
#                                             overview  popularity  \
# 0  Inspired by actual events, a group of 12 year ...    2.815228
# 1  A maverick New York hedge fund trader with unc...    0.174311
# 2  Tom (Joseph Gordon-Levitt), greeting-card writ...   45.610993
# 3  A young woman inherits an old hotel in Louisia...    8.022122
# 4  After a car accident, Michelle awakens to find...   53.698683
#
#                                 production_companies  ... runtime  \
# 0           [{'name': 'AST Studios', 'id': '75277'}]  ...    90.0
# 1                                                 []  ...   103.0
# 2  [{'name': 'Fox Searchlight Pictures', 'id': '4...  ...    95.0
# 3                                                 []  ...    87.0
# 4  [{'name': 'Paramount Pictures', 'id': '4'}, {'...  ...   103.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1                                                 []  Released
# 2  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4                                                 []  Released
#
#                                              tagline                 title  \
# 0                                 Death is trending.               #Horror
# 1                                     Money for Life       Supercapitalist
# 2                It was almost like falling in love.  (500) Days of Summer
# 3  The seven dreaded gateways to Hell are conceal...            The Beyond
# 4                       Monsters come in many forms.   10 Cloverfield Lane
#
#   vote_average vote_count  movie_id  \
# 0          3.3         52  301325.0
# 1          3.5          2       NaN
# 2          7.2       2904   19913.0
# 3          6.6        117       NaN
# 4          6.8       2468  333371.0
#
#                                                 cast  \
# 0  [{"cast_id": 0, "character": "Alex's 12-Step F...
# 1                                                NaN
# 2  [{"cast_id": 4, "character": "Tom Hansen", "cr...
# 3                                                NaN
# 4  [{"cast_id": 2, "character": "Michelle", "cred...
#
#                                                 crew
# 0  [{"credit_id": "545bbac70e0a261fb6002329", "de...
# 1                                                NaN
# 2  [{"credit_id": "52fe47f99251416c750abaa5", "de...
# 3                                                NaN
# 4  [{"credit_id": "57627624c3a3680682000872", "de...
#
# [5 rows x 23 columns]

# %% [markdown]
# Next we will modify the cast. As shown below, a movie has multiple cast members, and each member has a cast_id, a character, a credit_id, a gender, an id, a name, and an order.

# %%
df.iloc[0]["cast"]
# Out:
# '[{"cast_id": 0, "character": "Alex\'s 12-Step Friend", "credit_id": "545bba84c3a3685358001b80", "gender": 1, "id": 343, "name": "Taryn Manning", "order": 1}, {"cast_id": 1, "character": "Sam\'s Mom", "credit_id": "545bba8a0e0a261fad0023f6", "gender": 1, "id": 10871, "name": "Natasha Lyonne", "order": 2}, {"cast_id": 2, "character": "Alex Cox", "credit_id": "545bba8fc3a36853500018a4", "gender": 1, "id": 2838, "name": "Chlo\\u00eb Sevigny", "order": 3}, {"cast_id": 3, "character": "Mr. Cox", "credit_id": "545bba94c3a3685353001a56", "gender": 2, "id": 9296, "name": "Balthazar Getty", "order": 4}, {"cast_id": 4, "character": "Dr. White", "credit_id": "545bba990e0a261fb900220b", "gender": 2, "id": 16327, "name": "Timothy Hutton", "order": 5}, {"cast_id": 5, "character": "Lisa", "credit_id": "545bba9ec3a368535d001e67", "gender": 1, "id": 210573, "name": "Lydia Hearst", "order": 6}, {"cast_id": 6, "character": "Mom", "credit_id": "545bbaa4c3a368535d001e6b", "gender": 0, "id": 180425, "name": "Jessica Blank", "order": 7}, {"cast_id": 7, "character": "Molly", "credit_id": "545bbab1c3a3685362001a0f", "gender": 0, "id": 1102331, "name": "Annabelle Dexter-Jones", "order": 8}, {"cast_id": 15, "character": "Tatiana (voice)", "credit_id": "572f9a8792514102ac000642", "gender": 1, "id": 61111, "name": "Tara Subkoff", "order": 9}]'

# %%
#go through each row
for index, row in df.iterrows():
    
    casts = []
    line = str(row["cast"])
    cur_casts = line.split('},')
    
    del cur_casts[-1]
  
    #transform info for each genre
    for cast in cur_casts:
       
        m = re.search("cast_id\": (\d*), \"character\": \"(.*)\", \"credit_id\": \"(.*)\", \"gender\": (.*), \"id\": (\d*), \"name\": \"(.*)\", \"order\": (.*)", cast)
       
        cur_cast_id = m.groups()[0]
        cur_character = m.groups()[1]
        cur_credit_id = m.groups()[2]
        cur_gender = m.groups()[3]
        cur_id = m.groups()[4]
        cur_name = m.groups()[5]
        cur_order = m.groups()[6]

        cur_info = {}
        cur_info["cast_id"] = cur_cast_id
        cur_info["character"] = cur_character
        cur_info["credit_id"] = cur_credit_id
        cur_info["gender"] = cur_gender
        cur_info["id"] = cur_id
        cur_info["name"] = cur_name
        cur_info["order"] = cur_order

        casts.append(cur_info)
        
    df.at[index, "production_countries"] = casts

# %% [markdown]
# Next we will modify the crew. As shown below, each crew has multiple members, and each member has a credit_id, a department, a gender, an id, a job, and a name.

# %%
df.iloc[0]["crew"]
# Out:
# '[{"credit_id": "545bbac70e0a261fb6002329", "department": "Writing", "gender": 1, "id": 61111, "job": "Screenplay", "name": "Tara Subkoff"}, {"credit_id": "545bbabf0e0a261fb9002212", "department": "Directing", "gender": 1, "id": 61111, "job": "Director", "name": "Tara Subkoff"}, {"credit_id": "545bbae4c3a36853500018a8", "department": "Production", "gender": 1, "id": 61111, "job": "Producer", "name": "Tara Subkoff"}, {"credit_id": "545bbad3c3a3685358001b92", "department": "Production", "gender": 0, "id": 1382445, "job": "Producer", "name": "Jason Ludman"}, {"credit_id": "545bbadbc3a368535d001e74", "department": "Production", "gender": 0, "id": 1382446, "job": "Producer", "name": "Oren Segal"}, {"credit_id": "545bbaf3c3a3685358001b9d", "department": "Production", "gender": 0, "id": 1382448, "job": "Producer", "name": "Brendan Walsh"}]'

# %%
#go through each row
for index, row in df.iterrows():
    
    crews = []
    line = str(row["crew"])
    cur_crews = line.split('},')
    
    del cur_crews[-1]
   
    #transform info for each genre
    for crew in cur_crews:
        
        m = re.search("credit_id\": (.*), \"department\": \"(.*)\", \"gender\": (.*), \"id\": (.*), \"job\": (.*), \"name\": (.*)\"", crew)
       
        cur_credit_id = m.groups()[0]
        cur_department = m.groups()[1]
        cur_gender = m.groups()[2]
        cur_id = m.groups()[3]
        cur_job = m.groups()[4]
        cur_name = m.groups()[5]

        cur_info = {}
        cur_info["credit_id"] = cur_credit_id
        cur_info["department"] = cur_department
        cur_info["gender"] = cur_gender
        cur_info["id"] = cur_id
        cur_info["job"] = cur_job
        cur_info["name"] = cur_name

        crews.append(cur_info)
        
    df.at[index, "crew"] = crews

# %%
display(df.head())
# Out:
#                                   index    budget  \
# 0                               #Horror   1500000
# 1                       $upercapitalist         0
# 2                  (500) Days of Summer   7500000
# 3  ...E tu vivrai nel terrore! L'aldilà         0
# 4                   10 Cloverfield Lane  15000000
#
#                                               genres  \
# 0  [{'id': '18', 'name': 'Drama'}, {'id': '9648',...
# 1                                                 []
# 2  [{'id': '35', 'name': 'Comedy'}, {'id': '18', ...
# 3                                                 []
# 4  [{'id': '53', 'name': 'Thriller'}, {'id': '878...
#
#                             homepage      id  \
# 0      http://www.hashtaghorror.com/  301325
# 1        http://supercapitalist.net/  119458
# 2                 http://500days.com   19913
# 3                                NaN   19204
# 4  http://www.10cloverfieldlane.com/  333371
#
#                                             keywords original_language  \
# 0                                                 []                de
# 1                                                 []                en
# 2  [{"id": 248, "name": "date"}, {"id": 572, "nam...                en
# 3  [{"id": 612, "name": "hotel"}, {"id": 1706, "n...                it
# 4  [{"id": 1930, "name": "kidnapping"}, {"id": 23...                en
#
#                                             overview  popularity  \
# 0  Inspired by actual events, a group of 12 year ...    2.815228
# 1  A maverick New York hedge fund trader with unc...    0.174311
# 2  Tom (Joseph Gordon-Levitt), greeting-card writ...   45.610993
# 3  A young woman inherits an old hotel in Louisia...    8.022122
# 4  After a car accident, Michelle awakens to find...   53.698683
#
#                                 production_companies  ... runtime  \
# 0           [{'name': 'AST Studios', 'id': '75277'}]  ...    90.0
# 1                                                 []  ...   103.0
# 2  [{'name': 'Fox Searchlight Pictures', 'id': '4...  ...    95.0
# 3                                                 []  ...    87.0
# 4  [{'name': 'Paramount Pictures', 'id': '4'}, {'...  ...   103.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1                                                 []  Released
# 2  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4                                                 []  Released
#
#                                              tagline                 title  \
# 0                                 Death is trending.               #Horror
# 1                                     Money for Life       Supercapitalist
# 2                It was almost like falling in love.  (500) Days of Summer
# 3  The seven dreaded gateways to Hell are conceal...            The Beyond
# 4                       Monsters come in many forms.   10 Cloverfield Lane
#
#   vote_average vote_count  movie_id  \
# 0          3.3         52  301325.0
# 1          3.5          2       NaN
# 2          7.2       2904   19913.0
# 3          6.6        117       NaN
# 4          6.8       2468  333371.0
#
#                                                 cast  \
# 0  [{"cast_id": 0, "character": "Alex's 12-Step F...
# 1                                                NaN
# 2  [{"cast_id": 4, "character": "Tom Hansen", "cr...
# 3                                                NaN
# 4  [{"cast_id": 2, "character": "Michelle", "cred...
#
#                                                 crew
# 0  [{'credit_id': '"545bbac70e0a261fb6002329"', '...
# 1                                                 []
# 2  [{'credit_id': '"52fe47f99251416c750abaa5"', '...
# 3                                                 []
# 4  [{'credit_id': '"57627624c3a3680682000872"', '...
#
# [5 rows x 23 columns]

# %% [markdown]
# The final tidied table is shown above. Now, we will being doing exploratory analysis on our data.

# %% [markdown]
# ## 2.0 - Exploratory Data Analysis

# %%
df['missing'] = 0

genres = []
revenues = []

#get the genre and revenue data from the table
for index, row in df.iterrows():
    l = list(map(lambda e: e['name'],row['genres']))
    genres += l;
    revenues += [row['revenue']] * len(row['genres'])

#find the missing data in the table    
for index, row in df.iterrows():
    
    missing = 0
    
    #if the budget is missing
    if row['budget'] == 0:
        missing += 1
        
    #if the genres are missing    
    if row['genres'] == []:
        missing += 1
        
    #if the homepage is missing    
    if row['homepage'] == np.NaN:
        missing += 1
        
    #if the keywords are missing    
    if row['keywords'] == []:
        missing += 1
        
    #if the production companies are missing    
    if row['production_companies'] == []:
        missing += 1
        
    #if the production countries are missing    
    if row['production_countries'] == []:
        missing += 1
        
    #if the spoken languages are missing    
    if row['spoken_languages'] == []:
        missing += 1
        
    #if the revenue is missing    
    if row['revenue'] == 0:
        missing += 1 
        
    #if the tagline is missing    
    if row['tagline'] == np.NaN:
        missing += 1
        
    #if the cast info is missing    
    if row['cast'] == np.NaN:
        missing += 1
        
    #if the crew info is missing    
    if row['crew'] == np.NaN:
        missing += 1
    
    df.at[index, 'missing'] = missing

# %%
display(df.corr())
# Out:
#                 budget        id  popularity   revenue   runtime  \
# budget        1.000000 -0.089163    0.505545  0.730603  0.269966
# id           -0.089163  1.000000    0.031267 -0.050527 -0.153521
# popularity    0.505545  0.031267    1.000000  0.644725  0.225761
# revenue       0.730603 -0.050527    0.644725  1.000000  0.251344
# runtime       0.269966 -0.153521    0.225761  0.251344  1.000000
# vote_average  0.093112 -0.270644    0.273952  0.197337  0.375036
# vote_count    0.593224 -0.004113    0.778214  0.781471  0.272258
# movie_id     -0.086309  0.999903    0.044541 -0.046466 -0.157726
# missing      -0.422248  0.241596   -0.331544 -0.324332 -0.291237
#
#               vote_average  vote_count  movie_id   missing
# budget            0.093112    0.593224 -0.086309 -0.422248
# id               -0.270644   -0.004113  0.999903  0.241596
# popularity        0.273952    0.778214  0.044541 -0.331544
# revenue           0.197337    0.781471 -0.046466 -0.324332
# runtime           0.375036    0.272258 -0.157726 -0.291237
# vote_average      1.000000    0.313024 -0.267474 -0.290222
# vote_count        0.313024    1.000000  0.005814 -0.328812
# movie_id         -0.267474    0.005814  1.000000  0.239065
# missing          -0.290222   -0.328812  0.239065  1.000000

# %%
#histogram for the revenue and budget

sort = df.sort_values('revenue', ascending=False )

plt.figure()
plt.hist(df['revenue'])
plt.hist(df['budget'])
# Out:
# (array([3.54e+03, 7.73e+02, 2.50e+02, 1.42e+02, 5.10e+01, 3.40e+01,
#         1.40e+01, 3.00e+00, 0.00e+00, 1.00e+00]),
#  array([0.00e+00, 3.80e+07, 7.60e+07, 1.14e+08, 1.52e+08, 1.90e+08,
#         2.28e+08, 2.66e+08, 3.04e+08, 3.42e+08, 3.80e+08]),
#  <a list of 10 Patch objects>)

# %%
#histogram for revenue 

plt.figure()
display()
n, bins, patches = plt.hist(df['revenue'], log=True)

# %%
genre_revenue = {}
genre_count = {}

data = {'genre' : genres, 'revenue' : revenues}
data = pd.DataFrame(data)

#get the data
for index, row in data.iterrows():
    
    cur_genre = row["genre"]
    cur_revenue = row["revenue"]
    
    #if has seen the genre before
    if cur_genre in genre_revenue:
        genre_revenue[cur_genre] += cur_revenue
        genre_count[cur_genre] += 1
        
    #if haven't seen the genre before    
    else:
        genre_revenue[cur_genre] = cur_revenue
        genre_count[cur_genre] = 1
        
genre_avg_revenue = {}

#calculate the average revenue for each genre
for genre in genre_revenue.keys():
    genre_avg_revenue[genre] = genre_revenue[genre] / genre_count[genre]
    
genre_avg_revenue
# Out:
# {'Drama': 57376553.47837658,
#  'Mystery': 67282364.09047619,
#  'Horror': 48367807.523545705,
#  'Comedy': 71271402.55693069,
#  'Thriller': 90793990.08482143,
#  'Science': 149063947.25941423,
#  'Romance': 75284527.87214611,
#  'Action': 134062717.15583174,
#  'Crime': 61121216.74222222,
#  'Adventure': 205881389.34361234,
#  'Fantasy': 184920267.51546392,
#  'History': 62803934.0,
#  'Documentary': 22229625.884615384,
#  'Music': 56522535.80487805,
#  'War': 70635276.14285715,
#  'Animation': 232988795.21126762,
#  'Family': 176326254.23076922,
#  'Western': 69494073.4,
#  'Foreign': 1014316.8181818182,
#  'TV': 0.0}

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 8), dpi=80, facecolor='w', edgecolor='k')

objects = genre_avg_revenue.keys()
y_pos = np.arange(len(objects))
performance = genre_avg_revenue.values()

plt.bar(y_pos, performance, align='center', alpha=1)
plt.xticks(y_pos, objects)
plt.ylabel('Average Revenue')
plt.title('Average Revenue vs. Genre')

plt.show()

# %%
#calculate all occurences for each production company

all_prod_comps = {}

for index, row in df.iterrows():
    prod_comps = row["production_companies"]
    
    for p_c in prod_comps:
        if p_c["name"] in all_prod_comps:
            all_prod_comps[p_c["name"]] += 1
        else:
            all_prod_comps[p_c["name"]] = 1
        
all_prod_comps
# Out:
# {'AST Studios': 1,
#  'Fox Searchlight Pictures': 55,
#  'Watermark': 1,
#  'Paramount Pictures': 223,
#  'Bad Robot': 8,
#  'Mad Chance': 7,
#  'Jaret Entertainment': 1,
#  'Walt Disney Pictures': 87,
#  'Firm Films': 8,
#  'Media 8 Entertainment': 1,
#  'United Artists': 63,
#  'The Mark Gordon Company': 6,
#  'Fox Atomic': 3,
#  '20th Century Fox Home Entertainment': 1,
#  'WWE Studios': 5,
#  'Plan B Entertainment': 11,
#  'Regency Enterprises': 66,
#  'River Road Entertainment': 7,
#  'Film4': 26,
#  'Warner Bros.': 192,
#  'Cloud Eight Films': 3,
#  'Path\\u00e9': 9,
#  'Everest Entertainment': 1,
#  'Columbia Pictures': 164,
#  'Revolution Studios': 25,
#  '3 Arts Entertainment': 6,
#  'Bay Films': 2,
#  'Latina Pictures': 2,
#  'The Weinstein Company': 35,
#  'Di Bonaventura Pictures': 17,
#  'New Line Cinema': 126,
#  'Industry Entertainment': 4,
#  'Tribeca Productions': 7,
#  "Donners' Company": 14,
#  'Cheyenne Enterprises': 9,
#  'Alcon Entertainment': 20,
#  'Nu Image Entertainment GmbH': 1,
#  'Millennium Films': 17,
#  'Emmett/Furla Films': 11,
#  'Equity Pictures Medienfonds GmbH & Co. KG III': 2,
#  'Universal Pictures': 252,
#  'Mikona Productions GmbH & Co. KG': 3,
#  'Original Film': 28,
#  'Universal Studios': 5,
#  'Marc Platt Productions': 10,
#  'Twentieth Century Fox Film Corporation': 183,
#  'Stanley Kubrick Productions': 3,
#  'Centropolis Entertainment': 8,
#  'Paradis Films': 1,
#  'Orly Films': 2,
#  'Shanghai Film Group Corporation': 1,
#  'Relativity Media': 75,
#  'Virgin Produced': 4,
#  'Mandeville Films': 9,
#  'This Is That Productions': 5,
#  'Y Productions': 1,
#  'Stephen J. Cannell Productions': 1,
#  'Media Rights Capital': 12,
#  'Metro-Goldwyn-Mayer (MGM)': 48,
#  'Cannell Studios': 1,
#  'LStar Capital': 8,
#  '33andOut Productions': 1,
#  '40 Acres & A Mule Filmworks': 6,
#  'Spyglass Entertainment': 36,
#  'Fox 2000 Pictures': 43,
#  'DNA Films': 10,
#  'Figment Films': 2,
#  'Sociedad General de Cine S.A.': 1,
#  'UK Film Council': 31,
#  'Anthem Pictures': 1,
#  'Wonderland Sound and Vision': 5,
#  'EuropaCorp': 15,
#  '3DTK': 1,
#  'Feelgood Entertainment': 1,
#  'TriStar Pictures': 42,
#  'Sheen Productions': 1,
#  'Dark Horse Entertainment': 7,
#  'Ghost House Pictures': 7,
#  'Silver Nitrate Films': 2,
#  'Virtual Studios': 7,
#  'Legendary Pictures': 32,
#  'Hollywood Gang Productions': 3,
#  'Atmosphere Entertainment MM': 6,
#  'Nimar Studios': 4,
#  'Franchise Pictures': 16,
#  'Tree Line Films': 3,
#  'Lionsgate': 47,
#  'Saga Film': 2,
#  'Mobra Films': 1,
#  'Mindshare Media': 1,
#  'Centrul National al Cinematografiei (CNC)': 1,
#  'McCann-Erickson': 1,
#  'Televiziunea Romana (TVR1)': 1,
#  'Miramax Films': 76,
#  'Mid Atlantic Films': 5,
#  'Stuber Productions': 7,
#  'Universal': 2,
#  'Moving Picture Company (MPC)': 7,
#  'Ingenious Film Partners': 29,
#  '1492 Pictures': 15,
#  'Dune Entertainment': 59,
#  'Constantin Film Produktion': 14,
#  'Bernd Eichinger Productions': 1,
#  'Midnight Sun Pictures': 1,
#  'Dispictures': 1,
#  'Georgia International Films': 1,
#  'Columbia Pictures Corporation': 71,
#  'Happy Madison Productions': 18,
#  'Anonymous Content': 12,
#  'Summit Entertainment': 48,
#  'Redeemable Features': 1,
#  'FilmColony': 1,
#  'Miramax': 3,
#  'Allied Artists Pictures': 1,
#  'Orion Pictures': 11,
#  'Imagine Entertainment': 35,
#  'France 2 Cin\\u00e9ma': 17,
#  'Fid\\u00e9lit\\u00e9 Productions': 3,
#  'Le Studio Canal+': 3,
#  'Centre National de la Cin\\u00e9matographie': 3,
#  'Gimages 5': 1,
#  'Nu Image Entertainment': 1,
#  'Hofflund/Polone': 2,
#  'Focus Films': 4,
#  'Starz Animation': 3,
#  'Tim Burton Productions': 8,
#  'DreamWorks SKG': 73,
#  'Witt/Thomas Productions': 1,
#  'Depth of Field': 4,
#  'McLaughlin Films': 1,
#  'Walt Disney': 4,
#  'Gaylord Films': 6,
#  'Dylan Sellers Productions': 3,
#  'Wildwood Enterprises': 5,
#  'Revolution Films': 7,
#  'BBC Films': 35,
#  'Baby Cow Productions': 2,
#  'EM Media': 7,
#  'Scion Films': 12,
#  'Recorded Pictures Company': 2,
#  'The Movie Network': 3,
#  'Millbrook Pictures': 1,
#  'Prospero Pictures': 1,
#  'Lago Film': 1,
#  'Ingenious Media': 14,
#  'Big Screen Productions': 10,
#  'Temple Hill Entertainment': 5,
#  'TSG Entertainment': 12,
#  'Giant Pictures': 1,
#  'Proscenium Films': 1,
#  'Walter Shenson Films': 1,
#  'Endgame Entertainment': 11,
#  'Wayans Bros. Entertainment': 3,
#  'IM Global': 9,
#  'Automatik Entertainment': 7,
#  'DC Comics': 16,
#  'Killer Films': 8,
#  'Escape Artists': 13,
#  'Black and Blu Entertainment': 1,
#  'Global Emerging Markets (GEM)': 1,
#  'Carnaby International': 2,
#  'Molinare Studios': 2,
#  'Mile High Productions': 1,
#  'Kevin Messick Productions': 2,
#  'Touchstone Pictures': 46,
#  'Caravan Pictures': 8,
#  'Newman/Tooley Films': 2,
#  'Joseph Nittolo Entertainment': 1,
#  'Fuzzy Door Productions': 2,
#  'Bluegrass Films': 4,
#  'Participant Media': 22,
#  'Imagenation Abu Dhabi FZ': 11,
#  'FilmNation Entertainment': 9,
#  'Before the Door Pictures': 4,
#  'Washington Square Films': 5,
#  'A24': 3,
#  'Senator Film Produktion': 3,
#  'Demarest Films': 4,
#  'The Ink Factory': 2,
#  'Potboiler Productions': 2,
#  'EMI Films Ltd.': 1,
#  'Thorn EMI Screen Entertainment': 1,
#  'Davis Entertainment': 26,
#  'Rogue': 1,
#  'QED International': 6,
#  'GreeneStreet Films': 5,
#  'Picturehouse Entertainment': 1,
#  'Sandcastle 5 Productions': 1,
#  'Goldcrest Films International': 4,
#  'National Film Finance Corporation (NFFC)': 1,
#  'Thousand Words': 1,
#  'Warner Independent Pictures (WIP)': 3,
#  'Detour Filmproduction': 2,
#  'Mike Zoss Productions': 7,
#  'Studio Canal': 15,
#  'Focus Features': 23,
#  'Octagon Films': 3,
#  'Artina Films': 2,
#  'Epsilon Motion Pictures': 32,
#  'Baldwin Entertainment Group': 5,
#  'Dante Entertainment': 2,
#  'Crusader Entertainment': 2,
#  'ETIC Films': 5,
#  'Forge': 3,
#  'QI Quality International GmbH Co. KG': 1,
#  'Signature Pictures': 8,
#  'ApolloMedia Distribution': 4,
#  'Coco': 1,
#  'Film 111': 1,
#  'Jericho Productions Ltd.': 1,
#  'MFF (Sound of Thunder)': 1,
#  'Matrix Film Finance': 1,
#  'Charles K. Feldman Group': 1,
#  'Saturn Films': 11,
#  'Double Feature Films': 15,
#  'Jersey Films': 10,
#  '1984 Private Defense Contractors': 5,
#  'Cross Creek Pictures': 9,
#  'Exclusive Media Group': 9,
#  'Traveling Picture Show Company (TPSC)': 1,
#  'Free State Pictures': 3,
#  'Village Roadshow Pictures': 80,
#  'Groucho II Film Partnership': 2,
#  'DiNovi Pictures': 10,
#  'Pandora Pictures': 2,
#  'Baleuko S.L.': 1,
#  'Departamento de Cultura del Gobierno Vasco': 1,
#  'Amblin Entertainment': 40,
#  'Impact Pictures': 12,
#  'Studio Babelsberg': 26,
#  'Stillking Films': 7,
#  'Brandywine Productions': 1,
#  'Lonlink Productions': 1,
#  'Kut Productions': 1,
#  'Inside Track Films': 1,
#  'Charenton Productions Limited': 1,
#  'Lions Gate Films': 26,
#  'Vertigo Entertainment': 14,
#  'Gotham Group': 3,
#  'Tailor Made': 1,
#  'Mango Farms': 1,
#  'Screen Gems, Inc.': 1,
#  'Rainforest Films': 2,
#  'Working Title Films': 22,
#  'Bazelevs Production': 6,
#  'Abraham Productions': 1,
#  'Blue Dot Productions': 1,
#  'Castle Rock Entertainment': 31,
#  'O Entertainment': 1,
#  'Silver Pictures': 25,
#  'Vox3 Films': 1,
#  'Serenade Films': 1,
#  'Olympus Pictures': 2,
#  'Deer Path Productions': 1,
#  '3L Filmproduktion GmbH': 1,
#  'Bleiberg Entertainment': 3,
#  'Adam Productions': 1,
#  'Beverly Detroit': 3,
#  'Propaganda Films': 4,
#  'Clinica Estetico': 3,
#  'Intermedia': 1,
#  'Good Machine': 6,
#  'Gaumont': 6,
#  'Cin\\u00e9@': 2,
#  'Canal+': 71,
#  'Screen Australia': 7,
#  'Screen NSW': 2,
#  'France T\\u00e9l\\u00e9visions': 4,
#  'Hopscotch Features': 2,
#  'Sidney Kimmel Entertainment': 13,
#  'Seabourne Pictures': 1,
#  'Blinding Edge Pictures': 2,
#  'Contrafilm': 6,
#  'Plum Pictures': 2,
#  'Harbor Light Entertainment': 1,
#  'Cort/Madden Productions': 1,
#  'ATR Films': 1,
#  'MMP Erste Filmproduktions': 1,
#  'Splendid Pictures': 3,
#  'Maverick Films': 5,
#  'Himen\\u00f3ptero': 3,
#  'Telecinco Cinema': 4,
#  'Mod Producciones': 3,
#  'Canal+ Espa\\u00f1a': 8,
#  'Instituto de la Cinematograf\\u00eda y de las Artes Audiovisuales (ICAA)': 7,
#  'Beacon Communications': 6,
#  'T-Series': 1,
#  'Hari Om Entertainment Co.': 1,
#  'ARTE': 2,
#  'Inosan': 1,
#  'Das Kleine Fernsehspiel (ZDF)': 1,
#  '2929 Productions': 10,
#  'Out of the Blue... Entertainment': 3,
#  'Starbucks Entertainment': 1,
#  'Estudios Picasso': 2,
#  'NBC Universal Global Networks': 1,
#  'France 3 Cin\\u00e9ma': 7,
#  'Intermedia Films': 18,
#  'Path\\u00e9 Renn Productions': 9,
#  'Egmond Film & Television': 2,
#  'Pacifica Film': 1,
#  'IMF Internationale Medien und Film GmbH & Co. 3. Produktions KG': 3,
#  '21 Laps Entertainment': 10,
#  'Team Todd': 6,
#  'Roth Films': 3,
#  'SLM Production Group': 3,
#  'Josephson Entertainment': 5,
#  'New Upstairs Productions': 1,
#  'Fortis Films': 2,
#  'Dune Entertainment III': 20,
#  'Touchy Feely Films': 1,
#  'Sudden Storm Productions': 2,
#  'Treehouse Pictures': 2,
#  'Les Films Alain Sarde': 4,
#  'Rising Star': 6,
#  'Phoenix Pictures': 12,
#  'Limb from Limb Pictures': 1,
#  'Vinyl Films': 3,
#  'Arcadia Motion Pictures': 3,
#  'Wanda Visi\\u00f3n S.A.': 2,
#  'Scott Rudin Productions': 30,
#  'Boll Kino Beteiligungs GmbH & Co. KG': 3,
#  'Brightlight Pictures': 7,
#  'Herold Productions': 1,
#  'AZL Productions KG': 1,
#  'David Brown Productions': 2,
#  'MFP Munich Film Partners': 1,
#  'Phase 1 Productions': 1,
#  'Lions Gate Family Entertainment': 1,
#  'Crest Animation Production': 1,
#  'Sunswept Entertainment': 11,
#  'Bagdasarian Productions': 1,
#  'Renn Productions': 1,
#  'TF1 Films Production': 17,
#  'K.G Productions': 1,
#  'KC Medien': 2,
#  'Scott Free Productions': 23,
#  'Lucasfilm': 12,
#  'NGN Productions': 1,
#  'Glacier Films': 1,
#  'Screen Media Films': 1,
#  'Vertigo Films': 3,
#  'The Turman-Morrissey Company': 1,
#  'Atlas Entertainment': 13,
#  'Cannon Group': 2,
#  'Newmarket Capital Group': 9,
#  'Liveplanet': 1,
#  'Edward R. Pressman Film': 3,
#  'Malpaso Productions': 16,
#  'RatPac-Dune Entertainment': 4,
#  'Mad Chance Productions': 1,
#  'Zide-Perry Productions': 4,
#  'LivePlanet': 4,
#  'Arts Council of England': 6,
#  'British Broadcasting Corporation (BBC)': 9,
#  'Altavista Films': 1,
#  'Les Films du Losange': 2,
#  'Wega Film': 2,
#  'Hollywood Pictures': 21,
#  'Media Pro Pictures': 2,
#  'Allan Zeman Productions': 1,
#  'After Dark Films': 5,
#  'Remstar Productions': 1,
#  'Sweetpea Entertainment': 2,
#  'Redbus Pictures': 2,
#  'Baltimore Spring Creek Productions': 5,
#  'Lawrence Bender Productions': 6,
#  'Paramount Classics': 2,
#  'Persistent Entertainment': 2,
#  'Initial Entertainment Group (IEG)': 8,
#  'The Ladd Company': 3,
#  'Kalis Productions GmbH & Co. Zweite KG': 1,
#  'Middle Fork Productions': 1,
#  'Iguana Producciones': 1,
#  'Skylight Cinema Foto Art': 1,
#  'St. Tropez Films': 1,
#  'Screen Gems': 24,
#  'NPV Entertainment': 25,
#  'Baltimore Spring Creek Pictures': 1,
#  'Spring Creek Productions': 5,
#  'Fox Animation Studios': 1,
#  'Fox Family Films': 1,
#  'The Big Gun Project': 1,
#  'Gary Sanchez Productions': 10,
#  'Envision Entertainment': 3,
#  'Intandem Films': 2,
#  'Number 9 Films': 2,
#  'Tiger Aspect Pictures': 1,
#  'Father Features': 1,
#  'Audley Films': 1,
#  'Morgan Creek Productions': 7,
#  'The Canton Company': 2,
#  'AE Two Film Productions': 1,
#  'Panorama Films': 1,
#  'Oregon Film Factory': 1,
#  'The Safran Company': 6,
#  'Evergreen Media Group': 2,
#  'Olive Bridge Entertainment': 1,
#  'Sony Pictures Entertainment (SPE)': 7,
#  'Overbrook Entertainment': 3,
#  'Hideaway Pictures': 1,
#  'Traverse Media': 1,
#  'Hyde Park Films': 5,
#  'Alliance Films': 11,
#  'Telefilm Canada': 2,
#  'Pacific Data Images (PDI)': 8,
#  'Ixtlan': 2,
#  'Granada Film Productions': 4,
#  'Perdido Prod.': 1,
#  'Icon Productions': 6,
#  'Icon Entertainment International': 10,
#  'Dimension Films': 30,
#  'Groundswell Productions': 3,
#  'Hometown Films': 1,
#  'Williams Street': 1,
#  'First Look Pictures': 1,
#  'Alliance Atlantis Communications': 11,
#  'Serendipity Point Films': 4,
#  'Lucky Monkey Pictures': 4,
#  'Green Room Films': 1,
#  'Alvernia Studios': 1,
#  'LB Productions': 1,
#  'GK Films': 8,
#  'Lakeshore Entertainment': 31,
#  'Arlington Road Productions Corporation': 1,
#  'Gorai / Samuelson Productions': 1,
#  'Jerry Bruckheimer Films': 19,
#  'Stars Road Entertainment': 2,
#  'Farah Films & Management': 1,
#  'Renaissance Pictures': 2,
#  'Danmarks Radio (DR)': 5,
#  'Telepool': 2,
#  'AMC Pictures': 1,
#  'TV4 Sweden': 1,
#  'SF Norge': 1,
#  'Yleisradio (YLE)': 4,
#  'Svensk Filmindustri (SF)': 1,
#  'Juonifilmi': 1,
#  'TV2 Norge': 2,
#  'Film i V\\u00e4st': 7,
#  'Soundchef Studios': 1,
#  'Arion Communications Ltd.': 1,
#  'Dagsljus Filmequipment': 1,
#  'Sheba Films': 1,
#  'Sandline Production': 1,
#  'The Picture Factory': 3,
#  'Walden Media': 8,
#  'Babelsberg Film': 2,
#  'Mostow/Lieberman Productions': 1,
#  '80 Days Productions': 1,
#  'Spanknyce Films': 1,
#  'Aardman Animations': 5,
#  'Canal Plus': 10,
#  'Sofica Europacorp': 2,
#  'Avalanche Productions': 1,
#  'Gracie Films': 7,
#  'Decipher Entertainment': 1,
#  'Presque Isle Films': 1,
#  'LA Publicity': 1,
#  'Dino De Laurentiis Company': 7,
#  'Donner/Shuler-Donner Productions': 2,
#  'Rogue Pictures': 6,
#  'Why Not Productions': 5,
#  'Liaison Films': 1,
#  'Tezuka Production Company Ltd.': 1,
#  'Constantin Film': 1,
#  'TF1 Films Productions': 5,
#  'La Petite Reine': 3,
#  'Tri Pictures': 1,
#  'Sorolla Films': 1,
#  'Novo RPI': 1,
#  'uFilm': 6,
#  'Le Tax Shelter du Gouvernement F\\u00e9d\\u00e9ral de Belgique': 5,
#  'Cinema Vehicle Services': 1,
#  'CJ Entertainment': 4,
#  'Jean Doumanian Productions': 2,
#  "Eric's Boy": 1,
#  'Moving Pictures': 1,
#  'Capella International': 3,
#  'Bazmark Films': 4,
#  'Sony Pictures Classics': 13,
#  'Green Moon Productions': 1,
#  'Marvel Studios': 4,
#  'Prime Focus': 1,
#  'Open City Films': 1,
#  'Neal Street Productions': 5,
#  'Pandora Filmproduktion': 6,
#  'Monsoon Films Private Limited': 1,
#  'Pan Nalin Pictures': 1,
#  'Paramount Vantage': 10,
#  'Crystal Sky Worldwide': 3,
#  'StudioCanal': 38,
#  'M6 Films': 8,
#  'Cin\\u00e9Cin\\u00e9ma': 9,
#  'Babylon': 1,
#  'Babylon Films Limited': 1,
#  'M6': 6,
#  'GO Productions': 1,
#  'Vicarious Entertainment': 1,
#  'Bloodline Productions': 1,
#  'STX Entertainment': 3,
#  'Huayi Brothers Pictures': 1,
#  'Triptych Pictures': 1,
#  'Darko Entertainment': 4,
#  'Pictures in Paradise': 5,
#  'Media Development Authority (MDA)': 1,
#  'Screen Queensland': 1,
#  'Bait Productions': 1,
#  'Story Bridge Films': 1,
#  'Chris Lee Productions': 2,
#  'SuperMega': 1,
#  'Ultra Films': 1,
#  'TPS Star': 9,
#  'Empire Pictures': 1,
#  'Hyde Park Entertainment': 6,
#  'Goldsmith-Thomas Productions': 2,
#  'Asylum Films': 1,
#  'FM Entertainment': 1,
#  'JoBro Productions & Film Finance': 2,
#  'Initial Entertainment Group': 1,
#  'International Production Company': 5,
#  'Blue Star Pictures': 1,
#  'Living Films': 4,
#  'Sunchaser Entertainment': 1,
#  'Dino de Laurentiis Cinematografica': 3,
#  'Same Player': 1,
#  'PolyGram Filmed Entertainment': 15,
#  'Nickelodeon Movies': 19,
#  'Hawk Films': 3,
#  'Prospect Pictures': 1,
#  'Corner Store Entertainment': 3,
#  'Far Hills Pictures': 1,
#  'Kanzaman': 6,
#  'C-2 Pictures': 2,
#  'Eleventh Street Production': 1,
#  'Lunar Films': 1,
#  "Fonds Eurimages du Conseil de l'Europe": 3,
#  'Eurofilm St\\u00fadi\\u00f3': 1,
#  'St\\u00e1tn\\u00ed Fond CR pro Podporu a Rozvoj Cesk\\u00e9 Kinematografie': 1,
#  'Jakubisko Film Slovakia': 1,
#  'J&J Jakubisko Film': 1,
#  'Concorde Film Trust': 1,
#  'The Guber-Peters Company': 4,
#  'William Dozier Productions': 2,
#  'DC Entertainment': 5,
#  'Syncopy': 4,
#  'Cruel & Unusual Films': 1,
#  'Warner Bros. Animation': 5,
#  'Warner Premiere': 1,
#  'JTP Films': 1,
#  'Hasbro': 3,
#  'Nina Saxon Film Design': 2,
#  'Partizan': 1,
#  'CBS Films': 7,
#  "Mel's Cite du Cinema": 2,
#  'Les Films 21': 1,
#  'Journeyman Pictures': 3,
#  'Court 13 Pictures': 1,
#  'The Harold Greenberg Fund': 4,
#  'Ontario Media Development Corporation (OMDC)': 3,
#  'Telefilm Canada - Equity Investment Program': 1,
#  'Belle Pictures': 1,
#  'Geffen Pictures': 2,
#  'Ecosse Films': 2,
#  '2 Entertain': 1,
#  'DreamWorks Animation': 6,
#  'Identity Films': 1,
#  'Geffen Company, The': 1,
#  'Filmgate Films': 1,
#  'Faliro House Productions': 2,
#  'Detour Film Production': 1,
#  'Likely Story': 5,
#  'Apatow Productions': 4,
#  'Parts and Labor': 2,
#  'Gramercy Pictures': 5,
#  'Mpower Pictures': 2,
#  'Metanoia Films': 2,
#  'Burnside Entertainment': 1,
#  'Bella Productions': 1,
#  'Harpo Films': 4,
#  'Sean Daniel Company': 1,
#  'Kintop Pictures': 1,
#  'Filmf\\u00f6rderung Hamburg': 1,
#  'New South Wales Film & Television Office': 2,
#  'Pacific Film and Television Commission': 6,
#  'The Silence Productions': 1,
#  'Shangri-La Entertainment': 2,
#  'ImageMovers': 2,
#  'Horsethief Pictures': 1,
#  'Mandalay Vision': 2,
#  'Wind Dancer Productions': 1,
#  'Eddie Murphy Productions': 1,
#  'Mandalay Pictures': 9,
#  'CP Medien AG': 1,
#  'Camelot Pictures': 3,
#  'Networxx - Film Management': 1,
#  'Homegrown Pictures': 1,
#  'Black Entertainment Television (BET)': 1,
#  'Relativity Sports': 1,
#  'Laurence Mark Productions': 7,
#  'Hirsch': 1,
#  'R\\u00e9gion Nord-Pas-de-Calais': 1,
#  'Les Productions du Chicon': 1,
#  'Silverwood Films': 4,
#  'Electric City Entertainment': 2,
#  'The Zanuck Company': 7,
#  'Jinks/Cohen Company': 1,
#  'Deep River Productions': 3,
#  'New Regency Pictures': 24,
#  'Ed Friendly Productions': 1,
#  'Runteldat Entertainment': 3,
#  'The Collective Studios': 1,
#  'Friendly Films (II)': 1,
#  'Tiger Aspect Productions': 2,
#  'Worldview Entertainment': 7,
#  'Le Grisbi Productions': 3,
#  'Fine Line Features': 8,
#  'Lou Yi Inc.': 1,
#  'Academy Films': 2,
#  'HAL Films': 1,
#  'Mirage Enterprises': 11,
#  'Ikiru Films': 2,
#  'Televisi\\u00f3n Espa\\u00f1ola (TVE)': 4,
#  'Menageatroz': 1,
#  'Televisi\\u00f3 de Catalunya (TV3)': 3,
#  'Eivissa Productions': 1,
#  'Infinitum Nihil': 4,
#  'Head Gear Films': 2,
#  'Pegasus Film Partners': 1,
#  'Submarine Entertainment Distributors': 1,
#  'Protozoa Pictures': 6,
#  'Forward Pass': 6,
#  'Quickfire Films': 1,
#  'Noodles Production': 2,
#  'Instituto de Cr\\u00e9dito Oficial (ICO)': 3,
#  'ONO': 1,
#  'Ariane Marar\\u00eda Films': 1,
#  'Nix Films': 2,
#  'Eter Pictures': 1,
#  'Manto Films': 1,
#  'Pegaso Producciones': 1,
#  'Ibermedia European Community Program': 1,
#  'Amen Ra Films': 4,
#  'Imaginary Forces': 3,
#  'Milk & Honey': 1,
#  'Justin Pictures': 1,
#  'Linovo Productions GmbH & Co. KG': 1,
#  'Pacific Title and Art Studio': 1,
#  'Shaw Brothers': 1,
#  'Shawn Danielle Productions Ltd.': 1,
#  'Marvel Enterprises': 8,
#  'Crossbow Productions': 2,
#  'Karz Entertainment': 3,
#  'Rhombus Media': 6,
#  'O2 Filmes': 3,
#  'T\\u00e9l\\u00e9film Canada': 14,
#  'Bee Vine Pictures': 1,
#  'Asmik Ace Entertainment': 1,
#  'GAGA': 2,
#  'Fox Filmes do Brasil': 1,
#  'Ancine': 1,
#  'BNDES': 1,
#  'Cinema Investment': 1,
#  'Corus Entertainment': 5,
#  'Bedford Falls Productions': 3,
#  'Lonely Film Productions GmbH & Co. KG.': 3,
#  'Wild Bunch': 17,
#  'LGM Productions': 1,
#  'Les Productions du Tr\\u00e9sor': 3,
#  'Mars Distribution': 1,
#  'France T\\u00e9l\\u00e9vision': 5,
#  'Cin\\u00e9+': 8,
#  'France 3 Cinema': 5,
#  'Caneo Films': 1,
#  'Grisbi Productions': 1,
#  'France 4': 1,
#  'W9': 1,
#  'Chi-Fou-Mi Productions': 1,
#  'Daniel Bobker Productions': 2,
#  'Berrick Filmproduktion': 1,
#  'Marmont Productions': 1,
#  'Blood & Wine Productions': 1,
#  'Portman Entertainment Group': 1,
#  'B\\u00f3rd Scann\\u00e1n na h\\u00c9ireann': 3,
#  "Hell's Kitchen Films": 1,
#  'Film Science': 5,
#  'The Lab Of Madness': 1,
#  'Neighborhood Watch': 1,
#  'Hunting Lane Films': 2,
#  'Incentive Filmed Entertainment': 1,
#  'Chrysler Corporation': 1,
#  'Shade Pictures': 1,
#  'Motel Movies': 2,
#  'Motion Picture Corporation of America': 2,
#  'Bold Films': 9,
#  'Dean River Productions': 1,
#  'Bobby Jones Films LLC': 1,
#  'LIFE(n)': 1,
#  'De Line Pictures': 7,
#  'Yorktown Productions': 2,
#  'Park Ex Pictures': 1,
#  'Senator International': 2,
#  'Ghoulardi Film Company': 5,
#  'Artisan Entertainment': 4,
#  'Jewson Film': 1,
#  'Zininsa Film Production': 1,
#  'TiMe Film- und TV-Produktions GmbH': 1,
#  'Vif Babelsberger Filmproduktion GmbH & Co. Zweite KG': 1,
#  'Dog Eat Dog Films': 1,
#  'Iconolatry Productions Inc.': 1,
#  'Salter Street Films International': 1,
#  'IFC Films': 6,
#  'The Independent Film Channel Productions': 1,
#  'Lions Gate Television': 1,
#  'Ruby Films': 3,
#  'Sunrise Entertainment (II)': 1,
#  'Reliance Entertainment': 8,
#  'Hal Lieberman Company': 1,
#  'Atlantic Television': 1,
#  'CST Telecommunications': 1,
#  'Australian Film Finance Corporation (AFFC)': 5,
#  'Hopscotch Productions': 1,
#  'Alberta Film Entertainment': 3,
#  'Adam Fields Productions': 1,
#  'WCG Entertainment Productions': 2,
#  'Inferno International': 1,
#  'Closest to the Hole Productions': 4,
#  'Envision Entertainment Corporation': 2,
#  'Black Bear Pictures': 2,
#  'Aramid Entertainment Fund': 5,
#  'Str8jacket Creations': 1,
#  '4DH Films': 1,
#  'Wildgaze Films': 2,
#  'Irish Film Board': 10,
#  'Item 7': 1,
#  'Nu Image Films': 12,
#  'Langley Productions': 1,
#  'Thunder Road Productions': 1,
#  'Fuqua Films': 1,
#  'Bandai Visual Company': 3,
#  'Office Kitano': 1,
#  'Tokyo FM Broadcasting Co.': 2,
#  'Recorded Picture Company (RPC)': 2,
#  'Fuzzy Bunny Films (I)': 1,
#  'Sighvatsson Films': 2,
#  'Michael De Luca Productions': 5,
#  'Shady Acres Entertainment': 3,
#  'MGM': 1,
#  'Grosvenor Park Films LLP': 1,
#  'Dark Castle Entertainment': 16,
#  'Silver Reel': 9,
#  'EMJAG Productions': 2,
#  'Millar Gough Ink': 1,
#  'Studio 37': 4,
#  'Versus Entertainment': 1,
#  'PeaPie Films': 1,
#  'Campanile Productions': 1,
#  'Infinity Features Entertainment': 2,
#  'Irish Dreamtime': 5,
#  'Canadian Film or Video Production Tax Credit (CPTC)': 10,
#  'Province of British Columbia Film Incentive BC': 4,
#  'Butterfly Productions': 1,
#  'Jolie Pas': 1,
#  'Rafran Cinematografica': 1,
#  'New World Pictures': 5,
#  'Immortal Thoughts': 1,
#  'Armory Films': 1,
#  'Pelican Point Media': 1,
#  'Libido Cine': 1,
#  'Aquafilms': 1,
#  'Cappa Productions': 3,
#  "Cooper's Town Productions": 1,
#  'Eagle Vision Inc.': 1,
#  'Manitoba Film and Video Production Tax Credit': 3,
#  'Province of British Columbia Production Services Tax Credit': 4,
#  'Infinity Media': 1,
#  'Associated General Films': 2,
#  'Walt Disney Studios Motion Pictures': 5,
#  'Vita-Ray Dutch Productions (III)': 1,
#  'Itaca Films': 1,
#  'BN Films': 1,
#  'Brightside Entertainment': 1,
#  '1019 Entertainment': 1,
#  'Ibex Films': 1,
#  'Atlantis Pictures': 1,
#  'Schweizerische Radio- und Fernsehgesellschaft (SRG)': 1,
#  'Ascot Elite Entertainment Group': 1,
#  'Egli Film': 1,
#  'Teleclub AG': 1,
#  'Egoli Tossell Film AG': 2,
#  'Arte France': 3,
#  'Zanagar Films': 1,
#  'Vers\\u00e1til Cinema': 2,
#  'SBS Productions': 1,
#  'Polski Instytut Sztuki Filmowej': 2,
#  'Ivy Boy Productions': 1,
#  'NALA Films': 2,
#  'Misher Films': 4,
#  'L\\u00e9gende Entreprises': 1,
#  'Syalis DA': 1,
#  'An Olive Branch Productions': 1,
#  'Rollercoaster Entertainment': 1,
#  'Vortex Words Pictures': 1,
#  'Hannibal Pictures': 1,
#  'Trigger Street Productions': 3,
#  'Bagman (2009)': 1,
#  'Eon Productions': 10,
#  'Playtone': 9,
#  'Avon Production': 1,
#  'Kemp Company': 1,
#  'Nimbus Film Productions': 3,
#  'Mediastream Dritte Film GmbH & Co. Beteiligungs KG': 1,
#  'Warner Bros. Pictures': 6,
#  'David Kirschner Productions': 2,
#  'Frantic Films': 1,
#  'Maple Shade Films': 1,
#  'Artic Productions LLC': 1,
#  'Sweetland Films': 3,
#  'MACT Productions': 2,
#  'Videofilms': 1,
#  'Path\\u00e9 Pictures International': 5,
#  'Celador Films': 4,
#  'Vertigo Productions': 1,
#  "R\\u00e9gion Provence C\\u00f4te d'Azur": 1,
#  'La Fabrique de Films': 2,
#  'Toloda': 1,
#  'Centre National de la Cin\\u00e9matographie (CNC)': 8,
#  'Tiger Tail Entertainment': 1,
#  'Chicago Pacific Entertainment': 2,
#  'Hollywood Media Bridge': 2,
#  'LionsGate': 3,
#  'Clear Lake Entertainment': 1,
#  'Alpha Core': 2,
#  'Genre Films': 3,
#  'Simon Kinberg Productions': 1,
#  'Enigma Productions': 1,
#  'Participant Productions': 3,
#  'Tall Trees Productions': 1,
#  'ABC Pictures': 1,
#  'C.R.G. International': 1,
#  'Trademark Films': 1,
#  'New Artists Alliance': 1,
#  'Status Media & Entertainment': 1,
#  'Metropolitan Filmexport': 4,
#  'Lion Rock Productions': 4,
#  'Producers Circle': 2,
#  'Chicago Overcoat Productions': 1,
#  'Strike Entertainment': 7,
#  'Montecito Picture Company, The': 3,
#  'ATO Pictures': 1,
#  'Bill Kenwright Films': 1,
#  'Pathe': 4,
#  'Deutsche Filmf\\u00f6rderfonds (DFFF)': 4,
#  'R\\u00e9gion Ile-de-France': 6,
#  'National Lottery through UK Film Council': 2,
#  'Filmstiftung Nordrhein-Westfalen': 5,
#  'Cine Productions': 1,
#  'MMC Studios': 1,
#  'Tiggy Films': 1,
#  'Banque Populaire Images 9': 1,
#  'Cheri Productions': 1,
#  'VideoFilmes': 2,
#  'Globo filmes': 1,
#  'Lumiere': 2,
#  'Hank Levine Film': 2,
#  'Estudios Churubusco Azteca': 1,
#  'Gala Films': 1,
#  'Beagle Pug Films': 2,
#  'Parkway Pictures (I)': 1,
#  'Votiv Films': 2,
#  'A Space Between': 1,
#  'Marakesh Films': 1,
#  'Brad Grey Pictures': 1,
#  'CineSon Entertainment': 1,
#  'Filmsmith Productions': 1,
#  'Medici Entertainment': 1,
#  'Monarchy Enterprises B.V.': 2,
#  'Thunder Road Pictures': 8,
#  'IMF Internationale Medien und Film GmbH & Co. 2. Produktions KG': 1,
#  'MCL Films S.A.': 1,
#  'Carolco Pictures': 4,
#  'RCS Video': 1,
#  'Cliffhanger Productions': 1,
#  'EMI Films': 1,
#  'Compound B': 1,
#  'Underdogg Entertainment': 1,
#  'Mandragora Movies': 1,
#  'Agresywna Banda': 1,
#  'Anarchos Productions': 5,
#  'X-Filme Creative Pool': 5,
#  'Ascension Pictures': 1,
#  'ARD Degeto Film': 1,
#  'Cloud Atlas Productions': 1,
#  'Five Drops': 1,
#  'Media Asia Group': 1,
#  'Broken Lizard Industries': 1,
#  'MTV Films': 15,
#  'Haut et Court': 2,
#  'SCOPE Invest': 2,
#  'Scope Pictures': 3,
#  'Soficapital': 1,
#  'France 2 (FR2)': 2,
#  'Cofinova 5': 1,
#  'Films Distribution': 1,
#  'Steamroller Productions': 1,
#  'Castel Film Romania': 2,
#  'Bona Fide Productions': 3,
#  'Parkes/MacDonald Productions': 2,
#  'David Foster Productions': 4,
#  'Bel Air Entertainment': 6,
#  'Grive Productions': 5,
#  'Muskat Filmed Properties': 3,
#  'Bad Cop Bad Cop Film Productions': 1,
#  'Kouf/Bigelow Productions': 1,
#  'Hiett Designs of Las Vegas': 1,
#  'The Cantillon Company': 1,
#  'Allied Filmmakers': 3,
#  'Cinerenta Medienbeteiligungs KG': 5,
#  'Bright Cold Day Films': 1,
#  'Patchwork Productions': 1,
#  'Leverage Management': 2,
#  'Farraday Films': 1,
#  'Leverage Entertainment': 2,
#  'Becker International': 1,
#  'Claraflora': 1,
#  'NorthSee': 1,
#  'Prophecy Pictures Ltd.': 1,
#  'Across the River Productions': 1,
#  'Synchronistic Pictures': 1,
#  'Lipsync Productions': 6,
#  'Atlantic Swiss Productions': 1,
#  'Hermetof Pictures': 1,
#  'Magna Films': 1,
#  'Kalkronkie': 1,
#  'Artemis Films': 1,
#  'Lonely Dragon': 1,
#  'Robert Simonds Productions': 8,
#  'Tim Burton Animation Company': 1,
#  'Will Vinton Studios': 1,
#  'Laika Entertainment': 1,
#  'Maguire Entertainment': 1,
#  'Wild West Picture Show Productions': 2,
#  'Provident Films': 3,
#  'Affirm Films': 4,
#  'Sherwood Pictures': 1,
#  'Blackfriars Bridge Films': 2,
#  'Yari Film Group': 6,
#  'Bob Yari Productions': 4,
#  'ApolloProScreen Filmproduktion': 1,
#  "Bull's Eye Entertainment": 2,
#  'DEJ Productions': 1,
#  "Butcher's Run Films": 1,
#  'Ghost Robot': 1,
#  'Greencard Pictures': 1,
#  'MGM Television': 1,
#  'Trilogy Entertainment Group': 2,
#  'Creepshow Films Inc.': 1,
#  'BenderSpink': 8,
#  'Fipex Holding': 1,
#  'Campbell Grobman Films': 2,
#  'NeeNee Productions': 1,
#  'Capacity Pictures': 1,
#  'Live Entertainment': 3,
#  'Mediaworks': 1,
#  'Bungalow Productions': 1,
#  'Silver Lion Films': 2,
#  '360 Pictures': 1,
#  'Dribble Productions': 1,
#  'Cruel Productions': 1,
#  'Scottish Screen': 4,
#  'BBC Scotland': 1,
#  'Synchronicity Films': 1,
#  'Feature Film Project': 2,
#  'Cube Libre': 1,
#  'Harold Greenberg Fund': 2,
#  'Odeon Films': 2,
#  'Ontario Film Development Corporation': 2,
#  'Craven-Maddalena Films': 4,
#  'Outerbanks Entertainment': 1,
#  'Destination Films': 8,
#  'Andrea Sperling Productions': 2,
#  'Mindfire Entertainment': 1,
#  'Team Ninja': 1,
#  'VIP 4 Medienfonds': 3,
#  'Voltage Pictures': 4,
#  'Zentropa Entertainments': 5,
#  'SVT Drama': 1,
#  'Arte': 4,
#  'Memfis Film': 4,
#  'Angel films': 1,
#  'TV 1000': 1,
#  'Arte France Cin\\u00e9ma': 4,
#  'Westdeutscher Rundfunk (WDR)': 8,
#  'Blind Spot Pictures Oy': 1,
#  'Vrijzinnig Protestantse Radio Omroep (VPRO)': 1,
#  'Liberator Productions': 2,
#  'Icelandic Film': 1,
#  'Pain Unlimited GmbH Filmproduktion': 2,
#  'Trust Film Svenska': 1,
#  'Cinematograph A/S': 1,
#  ...}

# %% [markdown]
# ## 3.0 - Analysis

# %%
len(set(all_prod_comps))
# Out:
# 3175

# %% [markdown]
# ## Insights
